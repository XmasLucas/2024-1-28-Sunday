# %%
###重設###
import random
地獄=0
X連=0
迫擊砲=30
加農砲=20
弓箭塔=25
隱形炸彈=10
隱形大炸彈=15
隱形彈簧=20
地獄之塔=100
X連弩=50
成就=0
收法=10
閃法=20
帝法=50
法種=0
收益=0
總兵=1
法=4
蠻=1
氣=5
哥=1
巨=5
訓=0
水=100
礦空間=0
聖空間=0
兵空間=10
法空間=0
錢=1000
被用兵空間=10
防禦值=1

# %%
import random
input("遊戲中的文字不一定代表真實內容(因為程式會亂寫)")
次數=input("你要玩幾次")
防禦值=1
地獄=0
X連=0
房錢=錢
防水=水
迫擊砲=30
加農砲=20
弓箭塔=25
隱形炸彈=10
隱形大炸彈=15
隱形彈簧=20
地獄之塔=100
X連弩=50
成就=0
收法=10
閃法=20
帝法=50
法種=0
收益=0
總兵=1
法=4
蠻=1
氣=5
哥=1
巨=5
訓=0
水=100
礦空間=0
聖空間=0
被用兵空間=10
兵空間=10
法空間=0
錢=1000
家=input(f'你有{錢}元，你要買 1兵營=100，2礦場=500，3聖水=500，4訓練營=150，5法術爐=150，6成就=1000')
兵營=100
礦場=500
聖水=500
訓練營=150
法術爐=150
成就錢=1000
被用法空間=4
if 家=="1":
    if 錢-兵營<0:
        input('你買不起')
    else:    
        input(f"你剩{錢-兵營}元")
        input("你多了10個空間")
        錢-=兵營
        兵空間+=10
        被用兵空間+=10
if 家=="2":
    if 錢-礦場<0:
            input('你買不起')
    else:
        if 礦空間>3:
            input("沒那麼多礦場可以蓋")
        else:
            input(f"你剩{錢-礦場}元")
            input("你可以產錢了")
            錢-=礦場
            礦空間+=1
if 家=="3":
    if 錢-聖水<0:
        input('你買不起')
    else:
        if 聖空間>=4:
            input("沒那麼多聖水可以蓋")
        else:
            input(f"你剩{錢-聖水}元")
            input("你可以產聖水了")
            錢-=聖水
            聖空間+=1
if 家=="4":
    if 錢-訓練營<0:
        input('你買不起')
    else:
        if 訓>=1:
            input("沒那麼多訓練營可以蓋")
        else:
            input(f"你剩{錢-訓練營}元")
            input("你多了兵種:巨人")
            訓+=1
            錢-=訓練營
if 家=="5":
    if 錢-法術爐<0:
        input('你買不起')
    else:
        input(f"你剩{錢-法術爐}元")
        input("你多了4個法術空間")
        錢-=法術爐
        法空間+=4
        被用法空間+=4
        法種+=1
        if 法種==1:
            input('你可以製作閃電法術')
        if 法種==2:
            input('你可以製作收益法術')
        if 法種>=3:
            input('你可以製作帝王法術')
if 家=="6":
    if 錢-成就錢<0:
        input('你買不起')
    else:
        input(f"你剩{錢-成就錢}元")
        錢-=成就錢
        成就+=1
        input(f"你有{成就}成就")
for i in range(0,0+int(次數)):
    首頁=input("1產礦 2產聖水 3練兵 4製造法術 5買建築 6打劫 7升級 8買防禦建築 9不想玩了")

    if 首頁=="1":
        if 礦空間==1:
            input(f"你多了1000元，你有{錢+1000}元")
            錢+=1000
        if 礦空間==2:
            input(f"你多了2000元，你有{錢+2000}元")
            錢+=2000
        if 礦空間>=3:
            input(f"你多了4000元，你有{錢+4000}元")
            錢+=4000
    if 首頁=="2":
        if 聖空間>=1:
            input(f"你多了50點聖水，你有{水+50}點聖水")
            水+=500
        if 聖空間==2:
            input(f"你多了100點聖水，你有{水+100}點聖水")
            水+=1000
        if 聖空間==3:
            input(f"你多了150點聖水，你有{水+150}點聖水")
            水+=2000
    if 首頁=="3":
        if 訓==1:
            兵=input(f"你有{兵空間}個空間 1:蠻人1格 2:哥布林1格 3:巨人5格")
            if 兵=="1":
                人=input("你要幾隻")
                蠻人=float(人)
                if 蠻人*蠻>兵空間:
                    input('太滿了')
                else:
                    蠻總兵=蠻人*蠻
                    總兵+=蠻總兵
                    兵空間-=蠻人*蠻
                    input(f"你的戰力是{總兵}")
            if 兵=="2":
                林=input("你要幾隻")
                布林=float(林)
                if 布林*哥>兵空間:
                    input('太滿了')
                else:
                    布總兵=布林*哥
                    收益+=布總兵
                    兵空間-=布林*哥
                    input(f"你的收益是{收益}")
            if 兵=="3":
                大=input("你要幾隻")
                巨人=float(大)
                if 巨人*巨>兵空間:
                    input('太滿了')
                else:
                    巨總兵=巨人*巨
                    總兵+=總兵*巨總兵
                    兵空間-=巨人*巨
                    input(f"你的總兵是{總兵}")
        if 訓==0:
            兵=input(f"你有{兵空間}個空間 1:蠻人1格 2:哥布林1格 ")
            if 兵=="1":
                人=input("你要幾隻")
                蠻人=float(人)
                if 蠻人*蠻>兵空間:
                    input('太滿了')
                else:
                    蠻總兵=蠻人*蠻
                    總兵+=蠻總兵
                    兵空間-=蠻人*蠻
                    input(f"你的戰力是{總兵}")

            if 兵=="2":
                林=input("你要幾隻")
                布林=float(林)
                if 布林*哥>兵空間:
                    input('太滿了')
                else:
                    布總兵=布林*哥
                    收益+=布總兵
                    兵空間-=布林*哥
                    input(f"你的收益是{收益}")
    if 首頁=="4":
            if 法種==1:
                input(f"你有{法空間}個法術空間")
                練法=input('你可以製作  1:閃電法術1格')
                if 練法=='1':
                    煉製電法=input('你要幾瓶')
                    煉製法術=float(煉製電法)
                    if 煉製法術>法空間:
                        input('太滿了')
                    else:
                        法術=煉製法術*閃法
                        總兵+=法術
                        法空間-=煉製法術
                        input(f"你的戰力是{總兵}")
            if 法種==2:
                input(f"你有{法空間}個法術空間")
                練法=input('你可以製作  1:閃電法術1格  2:收益法術2格')
                if 練法=='1':
                    煉製電法=input('你要幾瓶')
                    煉製法術=float(煉製電法)
                    if 煉製法術>法空間:
                        input('太滿了')
                    else:
                        法術=煉製法術*閃法
                        總兵+=法術
                        法空間-=煉製法術
                        input(f"你的戰力是{總兵}")
                if 練法=='2':
                    煉製收法=input('你要幾瓶')
                    煉製法術=float(煉製收法)
                    if 煉製法術>法空間:
                        input('太滿了')
                    else:
                        法術=煉製法術*收法
                        收益+=法術
                        法空間-=煉製法術
                        input(f"你的收益是{收益}")
            if 法種>=3:
                input(f"你有{法空間}個法術空間")
                練法=input('你可以製作  1:閃電法術1格  2:收益法術2格  3:帝王法術5格')
                if 練法=='1':
                    煉製電法=input('你要幾瓶')
                    煉製法術=float(煉製電法)
                    if 煉製法術>法空間:
                        input('太滿了')
                    else:
                        法術=煉製法術*閃法
                        總兵+=法術
                        法空間-=煉製法術
                        input(f"你的戰力是{總兵}")
                if 練法=='2':
                    煉製收法=input('你要幾瓶')
                    煉製法術=float(煉製收法)
                    if 煉製法術>法空間:
                        input('太滿了')
                    else:
                        法術=煉製法術*收法
                        收益+=法術
                        法空間-=煉製法術
                        input(f"你的收益是{收益}")
                if 練法=='3':
                    煉製帝法=input('你要幾瓶')
                    煉製法術=float(煉製帝法)
                    if 煉製法術>法空間:
                        input('太滿了')
                    else:
                        法術=煉製法術*帝法
                        總兵+=法術
                        收益+=法術
                        法空間-=煉製法術
                        input(f"你的戰力是{總兵}，你的收益是{收益}")
    if 首頁=="5":
        家=input(f'你有{錢}元，你要買 1兵營=100，2礦場=500，3聖水=500，4訓練營=150，5法術爐=150，6成就=1000')
        兵營=100
        礦場=500
        聖水=500
        訓練營=150
        法術爐=150
        if 家=="1":
            input(f"你剩{錢-兵營}元")
            input("你多了10個空間")
            錢-=兵營
            兵空間+=10
            被用兵空間+=10
        if 家=="2":
    
            if 礦空間>=4:
                input("沒那麼多礦場可以蓋")
            else:
                input(f"你剩{錢-礦場}元")
                input("你可以產錢了")
                錢-=礦場
                礦空間+=1
        if 家=="3":
            if 聖空間>=4:
                input("沒那麼多聖水可以蓋")
            else:
                input(f"你剩{錢-500}元")
                input("你可以產聖水了")
                錢-=聖水
                聖空間+=1
        if 家=="4":
            if 訓>=1:
                input("沒那麼多訓練營可以蓋")
            else:
                input(f"你剩{錢-訓練營}元")
                input("你多了兵種:巨人")
                訓+=1
                錢-=訓練營
        if 家=="5":
            input(f"你剩{錢-法術爐}元")
            input("你有4個法術空間")
            錢-=法術爐
            法空間+=4
            被用法空間+=4
            法種+=1
            if 法種==1:
                input('你可以製作閃電法術')
            if 法種==2:
                input('你可以製作收益法術')
            if 法種==3:
                input('你可以製作帝王法術')
        if 家=="6":
            if 錢-成就錢<0:
                input('你買不起')
            else:
                input(f"你剩{錢-成就錢}元")
                錢-=成就錢
                成就+=1
                input(f"你有{成就}成就")
    if 首頁=="6":
        迫擊砲數=(random.randint(0,1))
        加農砲數=(random.randint(0,5))
        弓箭塔數=(random.randint(0,7))
        隱形炸彈數=(random.randint(0,4))
        隱形大炸彈數=(random.randint(0,2))
        隱形彈簧數=(random.randint(0,2))
        地獄之塔數=(random.randint(0,3))
        X連弩數=(random.randint(0,2))
        金庫=(random.randint(1000,5000))
        儲水庫=(random.randint(500,2000))
        戰鬥=迫擊砲數*迫擊砲+加農砲數*加農砲+弓箭塔數*弓箭塔+隱形炸彈數*隱形炸彈+隱形大炸彈數*隱形大炸彈+隱形彈簧數*隱形彈簧+地獄之塔數*地獄之塔
        input(f'有{迫擊砲數}台迫擊砲 有{加農砲數}台加農砲 有{弓箭塔數}座弓箭塔 有{地獄之塔數}個地獄之塔 有{X連弩數}個X連弩')
        input(f"有{儲水庫}點聖水，{金庫}元")
        要打嗎=input('要打嗎')
        if 要打嗎=="不要":
            問=input("1:找下一個 2:回首頁")
            if 問=='1':
                地獄=0
                X連=0
                迫擊砲數=(random.randint(0,1))
                加農砲數=(random.randint(0,5))
                弓箭塔數=(random.randint(0,7))
                隱形炸彈數=(random.randint(0,4))
                隱形大炸彈數=(random.randint(0,2))
                隱形彈簧數=(random.randint(0,2))
                地獄之塔數=(random.randint(0,3))
                X連弩數=(random.randint(0,2))
                金庫=(random.randint(1000,5000))
                儲水庫=(random.randint(500,2000))
                戰鬥=迫擊砲數*迫擊砲+加農砲數*加農砲+弓箭塔數*弓箭塔+隱形炸彈數*隱形炸彈+隱形大炸彈數*隱形大炸彈+隱形彈簧數*隱形彈簧+地獄之塔數*地獄之塔+X連弩數*X連弩
                input(f'有{迫擊砲數}台迫擊砲 有{加農砲數}台加農砲 有{弓箭塔數}座弓箭塔 有{地獄之塔數}個地獄之塔 有{X連弩數}個X連弩')
                要打嗎=input('要打嗎')
                if 要打嗎=="要":
                    多收錢=金庫*(收益/10)
                    多收水=儲水庫*(收益/10)
                    int(多收錢)
                    int(多收水)
                    p=(總兵/戰鬥)
                    if p>1:
                        p=1
                    int(p)
                    結果=p*100
                    if 結果>100:
                        結果=100
                    input(f'摧毀率{結果:.0f}%')
                    總兵=0
                    兵空間+=被用兵空間
                    法空間+=被用法空間
                    水+=儲水庫*p
                    錢+=金庫*p
                    input(f"你搶到了{儲水庫*p:.0f}點聖水，{金庫*p:.0f}元")
                    input(f"你多拿了{多收水}點聖水{多收錢}元")
                    input(f"你有{水:.0f}點聖水，{錢:.0f}元")
                    總兵=1
                    迫擊砲數=0
                    加農砲數=0
                    弓箭塔數=0
                    隱形炸彈數=0
                    隱形大炸彈數=0
                    隱形彈簧數=0
                    地獄之塔數=0
                    X連弩數=0
                    金庫=0
                    儲水庫=0
        if 要打嗎=="要":
            多收錢=金庫*(收益/10)
            多收水=儲水庫*(收益/10)
            int(多收錢)
            int(多收水)
            p=(總兵/戰鬥)
            if p>1:
                p=1
            int(p)
            結果=p*100
            if 結果>100:
                結果=100
            input(f'摧毀率{結果:.0f}%')
            總兵=0
            兵空間+=被用兵空間
            法空間+=被用法空間
            水+=儲水庫*p
            錢+=金庫*p
            input(f"你搶到了{儲水庫*p:.0f}點聖水，{金庫*p:.0f}元")
            input(f"你多拿了{多收水}點聖水{多收錢}元")
            input(f"你有{水:.0f}點聖水，{錢:.0f}元")
            總兵=1
            迫擊砲數=0
            加農砲數=0
            弓箭塔數=0
            隱形炸彈數=0
            隱形大炸彈數=0
            隱形彈簧數=0
            地獄之塔數=0
            X連弩數=0
            金庫=0
            儲水庫=0
    if 首頁=="7":
        升=input(f"你有{水}點聖水  1:野蠻人50點聖水 2:哥布林50點聖水 3:巨人70點聖水 4:閃電法術80點聖水 5:收益法術80點聖水 6:帝王法術110點聖水")
        if 升=="1":
            水-=50
            蠻+=20
            input("野蠻人升級了")
        if 升=="2":
            水-=50
            哥+=20
            input("哥布林升級了")
        if 升=="3":
            水-=70
            巨+=20
            input("巨人升級了")
        if 升=="4":
            水-=80
            閃法+=20
            input("閃電法術升級了")
        if 升=="5":
            水-=80
            收法+=20
            input("收益法術升級了")
        if 升=="6":
            水-=110
            帝法+=20
            input("帝王法術升級了")
    if 首頁=='8':
        家=input(f'你有{錢}元，你要買 1加農砲=100，2箭塔=100，3迫擊砲=300，4地獄之塔=500，5X連弩=450')
        加農砲錢=100
        箭塔錢=100
        迫擊砲錢=300
        地獄之塔錢=500
        X連弩錢=450
        if 家=="1":
            input(f"你剩{錢-加農砲錢}元")
            錢-=加農砲錢
            防禦值+=加農砲
        if 家=="2":
            input(f"你剩{錢-箭塔錢}元")
            錢-=箭塔錢
            防禦值+=弓箭塔
        if 家=="3":
            input(f"你剩{錢-迫擊砲錢}元")
            錢-=迫擊砲錢
            防禦值+=迫擊砲
        if 家=="4":
            input(f"你剩{錢-地獄之塔錢}元")
            錢-=地獄之塔錢
            防禦值+=地獄之塔
        if 家=="5":
            input(f"你剩{錢-X連弩錢}元")
            錢-=X連弩錢
            防禦值+=X連弩
        if 防禦值>=700:
            防禦值=700
            input("建築滿了")
    if 首頁=='9':
        break
    防禦=(random.randint(0,4))
    if 防禦==1:
        進攻=(random.randint(1,500))
        防=進攻/防禦值
        防結果=int(防*100)
        if 防結果>100:
            防結果=100
        input(f"你被攻擊了,摧毀率{防結果}%")
        if 錢*防>=錢*0.5:
            錢*=0.5
            錢*=0.5
        else:    
            錢-=錢*防
        if 水*防>=水*0.5:
            水*=0.5
            水*=0.5
        else:    
            水-=水*防
        input(f"你剩{水:.0f}點聖水，{錢:.0f}元")
input(f"你有{成就}個成就")
# Out:
# ''
